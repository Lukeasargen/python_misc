# %%
import math
import random
import pandas as pd
import numpy as np
from itertools import combinations
import time
import matplotlib.pyplot as plt

# %%
# Example DataFrame
data = [

["Deep Impact", 2.64],
["Joy.Ride.2001.720p", 0.7504],
["The.Negotiator.1998.1080p", 3.74],
["The Professor and the Madman", 0.5196],
["Kung Fu Panda 2 2011", 1.91],
["Women.Talking.2022.1080p", 1.31],
["The.Hurt.Locker.2008.1080p", 3.87],
["Becoming.Jane.2007.720p", 0.85],
["Primer.2004.1080p", 2.01],
["Clash.of.the.Titans.2010.720p", 1.09],
["Wrath.Of.The.Titans.2012.1080p", 2.73],
["Salt.2010", 0.8501],
["Hanna.2011.720p", 0.8002],
["Atomic.Blonde.2017", 2.61],
["Gunpowder.Milkshake.2021.720p", 0.9497],
["Kate.2021.720p", 0.7502],
["Love, Death & Robots S2", 0.6476],
["Love, Death & Robots S3", 1.01],
["Captain Phillips 2013", 3.16],
["Iron.Man.2008", 3.3],
["Iron.Man.2.2010", 2.94],
["Iron.Man.3.2013", 2.85],
["Avengers: Age of Ultron", 3.03],
["The.Avengers.2012", 3.14],
["Spider-Man.2002", 2.93],
["Spider-Man Into the Spider-Verse 2018", 3.22],
["Spider.Man.Homecoming.2017.1080p", 3.29],
["Spider-Man.3.2007", 3.36],
["Spider-Man.2.2004", 3.12],
["Captain.America.The.Winter.Soldier.2014", 3.08],
["Captain.America.The.First.Avenger.2011.1080p", 1.76],
["Black Panther Wakanda Forever 2022", 3.44],
["Thor.Ragnarok.2017", 2.85],
["Thor.2011.1080p", 2.57],
["Thor.Love.and.Thunder.2022.1080p", 2.96],
["Thor: The Dark World", 2.48],
["Doctor Strange", 2.04],
["Doctor Strange in the Multiverse of Madness", 2],
["Guardians.of.the.Galaxy.2014.1080p", 2.63],
["Guardians.of.the.Galaxy.Vol.2.2017.1080p", 3.54],
["Guardians.of.the.Galaxy.Vol.3.2023.1080p", 4.05],
["The.Incredible.Hulk.2008", 2.14],
["Charlie's Angels 2019", 2.45],
["Risky.Business.1983.1080p", 2.52],
["The.Unbearable.Weight.of.Massive.Talent 2022.1080p", 2.45],
["Gangster.Squad.2013.720p", 0.8501],
["Sherlock.Holmes.A.Game.of.Shadows.2011.1080p", 2.99],
["Sherlock.Holmes.2009.1080p", 3.28],

["Inglourious Basterds 2009", 3.38],
["American.Psycho.2000", 2.27],
["Fracture 2007", 2.71],
["Warrior.2011.1080p", 3.14],
["The.Da.Vinci.Code.2006", 4.36],
["Se7en.1995.1080p", 3.39],

["Eternal Sunshine of the Spotless Mind", 2.47],
["fresh 2022", 0.4765],
["Monsters.vs.Aliens.2009.720p", 0.6505],
["Jack Reacher: Never Go Back", 2.89],
["Django.Unchained.2012.720p", 1.52],
["Indiana.Jones.and.the.Temple.of.Doom.1984.1080p", 3.44],
["The.Shining.1980", 3.2],
["Ratatouille", 1.7],
["Terminator.2.Judgment.Day.1991", 3.69],
["Terminator.3.2003.1080p", 2.33],
["Terminator Genisys", 2.52],
["Monsters University", 2],
["The.Green.Mile.1999.1080p", 4.95],
["Braveheart.1995.1080p", 4.83],
["The.Devil.Wears.Prada.2006.1080p", 2.79],
["The.Lion.King.1994", 1.36],
["Split.2016", 2.17],
["A.Quiet.Place.2018", 2.64],
["Kingsman: The Secret Service", 2.81],
["Spider-Man.3.2007", 3.36],
["Kingsman: The Golden Circle", 3.71],
["John.Wick.2014.1080p", 2.43],
["Me.Before.You.2016.1080p", 2.29],
["The Matrix", 3.12],
["The Truman Show", 1.73],
["Toy.Story.2.1999", 2.11],
["The.Dark.Knight.2008", 3.21],
["The Amazing Spider-Man", 2.55],
["John Wick: Chapter 3 - Parabellum", 2.83],
["Deadpool.2.2018", 2.76],
["How to Train Your Dragon: The Hidden World", 2.08],
["John Wick: Chapter 2", 2.34],
["Nobody.2021.1080p", 2.68],
["Doctor Strange", 2.04],
["How.to.Train.Your.Dragon.2010", 2.06],
["How.to.Train.Your.Dragon.2.2014", 2.42],
["Deadpool", 2.89],
["Toy.Story.1995", 2.08],
["Spider-Man.2002", 2.93],
["The.Equalizer.2.2018.1080p", 2.41],
["The Wolf of Wall Street", 4.3],
["Jack Reacher 2012", 3.43],
["I.Robot.2004", 3.06],
["The Ring", 2.8],
["Schumacher", 1.09],
["Waterworld", 3.92],
["Snatch.2000.1080p", 2.57],
["The Bourne Ultimatum", 2.94],
["The.Bourne.Supremacy.2004.1080p", 2.99],
["The.Bourne.Legacy.2012.1080p", 3.91],
["Jason Bourne", 3.05],
["Ford.v.Ferrari.2019.1080p", 3.54],

["Leon.The.Professional.1994", 3.61],
["Inception.2010", 3.41],
["Call.Me.by.Your.Name.2017.720p", 1.16],
["Five Feet Apart", 1.95],
["Napoleon.Dynamite.2004.720p", 0.8509],
["Fearless.2006", 1.27],
["Chasing.Mavericks.2012.720p", 0.9003],
["The Shawshank Redemption 1994", 3.24],
["The Godfather", 3.31],
["Spirited Away", 2.59],
["Whiplash.2014.1080p", 2.32],
["Goodfellas.1990", 3.17],
["Pulp Fiction", 2.92],
["Nightcrawler", 2.43],
["Scarface.1983.1080p", 3.23],
["Poltergeist.1982", 3.37],
["Aliens 1986", 4.33],
["Top.Gun.1986", 3.04],
["The.New.York.Ripper.1982.1080p", 2.52],
["Raging.Bull.1980.720p", 1.07],
["Top.Gun.1986", 3.04],
["The.Usual.Suspects.1995.1080p", 2.34],
["This.Boys.Life.1993.720p", 0.9004],
["The.Virgin.Suicides.1999.720p", 0.8003],
["Theres.Something.About.Mary.1998.1080p", 2.94],
["Predator.1987", 2.51],
["Say.Anything.1989.720p", 0.8516],
["The.Bone.Collector.1999.1080p", 2.92],
["Return to the Blue Lagoon", 0.9004],
["Senseless.1998.720p", 0.7502],
["Runaway.Bride.1999.720p", 0.9995],
["Pretty Woman 1990", 3.24],
["Scent of a Woman", 3.92],
["Payback.1999", 0.7504],
["The.Game.1997", 2.74],
["The Cable Guy (1996)", 2.07],
["Dances with Wolves", 4.42],
["Con-Air.1997.1080p", 3.04],
["A.Walk.in.the.Clouds.1995", 0.8502],
["Meet.Joe.Black.1998.720p", 1.46],
["Lake.Placid.1999.720p", 0.7501],
["Speed.1994", 2.26],
["Saving Private Ryan", 5.79],
["The Devil's Advocate 1997", 3.73],
["Jurassic.Park.1993", 3.44],
["City.Of.Angels.1998.720p", 0.9496],
["Entrapment.1999.720p", 0.9005],
["Good.Will.Hunting.1997.1080p", 2.17],
["Heat.1995", 3.75],

# ["example", 1],
# ["example", 1],
# ["example", 1],
# ["example", 1],
# ["example", 1],

]
df = pd.DataFrame(data, columns=["title", "gb"])
# df
len(df)
# Out:
# 155

# %%
numbers = [0.950, 2.69, 0.8, 3.34, 0.9, 0.7, 2.28, 2.62]
# numbers = [2.65, 0.75, 0.85, 2.5]
numbers = df["gb"].values.tolist()

def min_sets(numbers, max_sum):
    numbers_with_index = list(enumerate(numbers))
    sets = [[0]]
    sums = [numbers[0]]
    for index, num in numbers_with_index[1:]:
        number_done = False
        for set_idx in range(len(sets)):
            if sums[set_idx] + num <= max_sum:
                sets[set_idx].append(index)
                sums[set_idx] += num
                number_done = True
                break
        if not number_done:
            sets.append([index])
            sums.append(num)
    return sets
numbers_np = np.array(numbers)
print(f"{len(numbers)} numbers to combine.")

plot_data = []
best_len = float('inf')
best_result = []
iteration = 0
counter = 0
t0 = time.time()
duration_s = 5
# input_indexes = np.arange(len(numbers_np))
# Force first fit by sorting the numbers descending
input_indexes = np.argsort(numbers_np)[::-1]
while True:
    result = min_sets(numbers_np[input_indexes], max_sum=14.98)
    if len(result)<best_len:
        best_len = len(result)
        # Undo the index shuffle
        best_result = [[input_indexes[i] for i in subset] for subset in result]
    input_indexes = np.random.permutation(len(numbers_np))
    # idx_map = {k:v for k, v in zip(np.arange(len(numbers_np)), input_indexes)}
    iteration += 1
    counter += 1
    if counter==1000:
        counter = 0
        if time.time()-t0 > duration_s:
            break
    # plot_data.append([best_len, len(result)])

print(f"Iterations tested: {iteration}. ({iteration/duration_s:.0f} per second)")
print(f"Minimum sets: {len(best_result)}")
# best_result
# Out:
# 155 numbers to combine.
# Iterations tested: 21000. (4200 per second)
# Minimum sets: 27

# %%
data_result = []
for subset in best_result:
    row = [sum([df.iloc[i, 1] for i in subset]), [df.iloc[i, 0] for i in subset], "+".join([f"{df.iloc[i, 1]}" for i in subset])]
    data_result.append(row)
pd.set_option('display.max_colwidth', None)
df_result = pd.DataFrame(data_result, columns=["Size", "Titles", "Sizes"])

# %%
df_result["Size"].sum()
# Out:
# 388.6493

# %%
df_result["Size"].sum()/15
# Out:
# 25.90995333333333

# %%
df_result
# df_result.sort_values(by="Size", ascending=False)
# Out:
#        Size
# 0   14.7900  \
# 1   14.9700
# 2   14.9800
# 3   14.9800
# 4   14.9300
# 5   14.8996
# 6   14.9100
# 7   14.8600
# 8   14.8500
# 9   14.9500
# 10  14.9700
# 11  14.9700
# 12  14.9500
# 13  14.9800
# 14  14.8200
# 15  14.6400
# 16  14.9405
# 17  14.9100
# 18  14.9700
# 19  14.9700
# 20  14.9500
# 21  14.9576
# 22  14.8500
# 23  14.8565
# 24  14.8395
# 25  14.4553
# 26   1.5003
#
#                                                                                                                                                                                                                                                                                                                                                                                                                Titles
# ...

# %%
# import os

# %%
# root = r"D:/"
# for src in os.listdir(root):
#     if not any(ext in src for ext in [".mkv", ".mp4"]): continue
#     dst = src.replace(" - HD", "").replace(" - ", " ")
#     os.rename(os.path.join(root, src), os.path.join(root, dst))

# %%
# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 4), dpi=300)
# df_plot = pd.DataFrame(plot_data, columns=["Best", "Current"])
# df_plot.plot(y=["Best"], ax=ax)

# %% [markdown]
# # Below are the chat gpts and one of my own

# %%
def find_sum_sets_backtrack(numbers, maximum_sum, current_set, result):
    # print(f"{current_set=}")
    # reject
    current_sum = sum(numbers[i] for i in current_set)
    if current_sum > maximum_sum:
        return
    # accept
    if len(current_set) > 0 and current_sum <= maximum_sum:
        result.append(current_set[:])

    
    for i in range(current_set[-1] + 1 if current_set else 0, len(numbers)):
        current_set.append(i)
        find_sum_sets_backtrack(numbers, maximum_sum, current_set, result)
        current_set.pop()

def find_sum_sets_list(numbers, maximum_sum):
    valid_sets = []
    find_sum_sets_backtrack(numbers, maximum_sum, [], valid_sets)
    return valid_sets



# numbers = [2.66, 2.21, 3.35, 1.19, 3.13, 0.85, 0.85, 4.88, 0.95, 3.79]
# numbers = [ 3.35, 1.19, 3.13, 0.85, 0.85, 4.88, 2.6, 2.65, 2.79]
numbers = [ 1.19, 3.13, 0.85, 0.9]
# numbers = df["gb"].values.tolist()
# valid_sets = find_sum_sets_list(numbers, maximum_sum=5)
# print(f"Sets of indexes for sums less than 5: {len(valid_sets)}")
# for canidate_set in valid_sets:
    # print(canidate_set)
    # values = [numbers[idx] for idx in canidate_set]
    # print(f"{sum(values)} {canidate_set} {values}")



def find_unique_combinations(data):
    def backtrack(index, selected):
        nonlocal shortest_combination
        if len(selected) >= len(shortest_combination):
            return

        if index == len(data):
            unique_selected = set()
            for sublist in selected:
                for num in sublist:
                    if num in unique_selected:
                        return
                    else:
                        unique_selected.add(num)
            if len(unique_selected) == len(unique_numbers):
                shortest_combination = selected[:]
            return

        # Include the current list at index
        selected.append(data[index])
        backtrack(index + 1, selected)
        selected.pop()

        # Skip the current list at index
        backtrack(index + 1, selected)

    unique_numbers = set(num for sublist in data for num in sublist)
    shortest_combination = data[:]
    backtrack(0, [])
    return shortest_combination

# Example usage
# data = [[0], [0, 1], [0, 2], [0, 2, 3], [0, 3], [1], [1, 2], [1, 2, 3], [1, 3], [2], [2, 3], [3]]
# data = valid_sets
# result = find_unique_combinations(data)
# for subset in result:
#     print(subset)

# %%
def find_sum_sets_backtrack(numbers, maximum_sum, current_set, result):
    # print(f"{current_set=}")
    # reject
    current_sum = sum(numbers[i] for i in current_set)
    if current_sum > maximum_sum:
        return
    # accept
    if len(current_set) > 0 and current_sum <= maximum_sum:
        result.append(current_set[:])

    
    for i in range(current_set[-1] + 1 if current_set else 0, len(numbers)):
        current_set.append(i)
        find_sum_sets_backtrack(numbers, maximum_sum, current_set, result)
        current_set.pop()

def find_sum_sets_list(numbers, maximum_sum):
    valid_sets = []
    find_sum_sets_backtrack(numbers, maximum_sum, [], valid_sets)
    return valid_sets

numbers = [
3.35, 1.19, 3.13, 0.85,
0.85, 4.88, 0.95, 3.79,
# 3.34, 0.9, 0.7, 2.28,
# 2.62, 3.21, 0.75, 0.95, 3.72,
# 0.999, 2.45, 2.52, 3.04,
# 1.93, 1.88, 3.08, 2.23, 2.72,
# 2.88, 2.5, 2.43, 3.61, 0.95,
# 0.8, 3.46, 3.42, 0.75, 3.31,
# 0.75, 3.26, 0.75, 0.65, 3.03,
# 2.99, 0.65, 2.6, 2.79, 2.65,
# 2.6, 2.65, 0.8, 3.23, 2.77,
# 0.8, 3.31,
]

# numbers = df["gb"].values.tolist()
# valid_sets = find_sum_sets_list(numbers, maximum_sum=5)
# print(f"Sets of indexes for sums less than 5: {len(valid_sets)}")
# for canidate_set in valid_sets:
#     print(canidate_set)
    # values = [numbers[idx] for idx in canidate_set]
    # print(f"{sum(values)} {canidate_set} {values}")

# %%
# This works, it returns all combinations of subsets that contain all the unique values
def find_unique_combinations(data):
    def backtrack(index, selected):
        if index == len(data):
            unique_selected = set()
            for sublist in selected:
                for num in sublist:
                    if num in unique_selected:
                        return
                    else:
                        unique_selected.add(num)
            if len(unique_selected) == len(unique_numbers):
                combinations.append(selected[:])
            return

        # Include the current list at index
        selected.append(data[index])
        backtrack(index + 1, selected)
        selected.pop()

        # Skip the current list at index
        backtrack(index + 1, selected)

    unique_numbers = set(num for sublist in data for num in sublist)
    combinations = []
    backtrack(0, [])
    return combinations

# Example usage
# data = [[0], [0, 1], [0, 2], [0, 2, 3], [0, 3], [1], [1, 2], [1, 2, 3], [1, 3], [2], [2, 3], [3]]
# data = valid_sets
# result = find_unique_combinations(data)
# print(f"Sets of subsets that contain all the data: {len(result)}")
# for combination in result:
#     print(combination)

# %%
# # Same as above, but exits early if subsets are longer than current shortests
# def find_unique_combinations(data):
#     def backtrack(index, selected):
#         nonlocal shortest_combination
#         if len(selected) >= len(shortest_combination):
#             return

#         if index == len(data):
#             unique_selected = set()
#             for sublist in selected:
#                 for num in sublist:
#                     if num in unique_selected:
#                         return
#                     else:
#                         unique_selected.add(num)
#             if len(unique_selected) == len(unique_numbers):
#                 shortest_combination = selected[:]
#             return

#         # Include the current list at index
#         selected.append(data[index])
#         backtrack(index + 1, selected)
#         selected.pop()

#         # Skip the current list at index
#         backtrack(index + 1, selected)

#     unique_numbers = set(num for sublist in data for num in sublist)
#     shortest_combination = data[:]
#     backtrack(0, [])
#     return shortest_combination

# # Example usage
# data = [[0], [0, 1], [0, 2], [0, 2, 3], [0, 3], [1], [1, 2], [1, 2, 3], [1, 3], [2], [2, 3], [3]]
# data = valid_sets
# result = find_unique_combinations(data)
# for combination in result:
#     print(combination)

# %%
# Use these lists of indexes
# Run backtracking again to find all combinations of these sets that use all the indexes
# Once one is found, set it as best, exit early on solutions that are longer

# %%
# df.sort_values(by="gb", ascending=False)

# %%
def combine_into_sets(numbers):
    numbers.sort(reverse=True)  # Sort the numbers in descending order

    min_sets = [float('inf')]

    optimal_sets = []

    def backtrack(start_index, current_set):

        # print(f"{start_index=} {current_set=}")

        if start_index == len(numbers):
            if len(current_set) < min_sets[0]:
                min_sets[0] = len(current_set)
                optimal_sets.clear()
                optimal_sets.extend(current_set)
            return
        
        for i in range(len(current_set)):
            if current_set[i] + numbers[start_index] <= 5:
                current_set[i] += numbers[start_index]
                backtrack(start_index + 1, current_set)
                current_set[i] -= numbers[start_index]

        if len(current_set) < min_sets[0]:
            backtrack(start_index + 1, current_set + [numbers[start_index]])

    backtrack(0, [])

    return [optimal_sets[i:i+1] for i in range(0, len(optimal_sets), 1)]

numbers = [2.66, 2.21, 3.35, 1.19, 3.13, 0.85, 0.85, 4.88, 0.95, 3.79]
# numbers = [2.65, 0.75, 0.85, 2.5]
# numbers = df["gb"].values.tolist()

numbers = [
3.35, 1.19, 3.13, 0.85,
0.85, 4.88, 0.95, 3.79,
# 3.34, 0.9, 0.7, 2.28,
# 2.62, 3.21, 0.75, 0.95, 3.72,
# 0.999, 2.45, 2.52, 3.04,
# 1.93, 1.88, 3.08, 2.23, 2.72,
# 2.88, 2.5, 2.43, 3.61, 0.95,
# 0.8, 3.46, 3.42, 0.75, 3.31,
# 0.75, 3.26, 0.75, 0.65, 3.03,
# 2.99, 0.65, 2.6, 2.79, 2.65,
# 2.6, 2.65, 0.8, 3.23, 2.77,
# 0.8, 3.31,
]

# result = combine_into_sets(numbers)
# print("Minimum number of sets:", len(result))
# print("Sets:", result)

# %%
# My algorithm using just pairs
# Create a NumPy array to store the sums of each pair
pairs_sum = np.zeros((len(df), len(df)))
for i in range(len(df)):
    pairs_sum[i][i] = df.iloc[i, 1]
    for j in range(i+1, len(df)):
        pairs_sum[i][j] = df.iloc[i, 1] + df.iloc[j, 1]
pairs_sum
        
def find_pairs(data, upper_limit=5, greedy=True):
    pairs = []
    pairs_sum = data.copy()
    # At most if should be half the length
    for i in range(len(pairs_sum)):
        # print(pairs_sum)
        canidate_vals = pairs_sum[np.where( np.logical_and((pairs_sum > 0), (pairs_sum <= upper_limit)) )]
        if len(canidate_vals)==0:
            return pairs
        max_val = np.max(pairs_sum[np.where( np.logical_and((pairs_sum > 0), (pairs_sum <= upper_limit)) )])
        max_list = np.argwhere(pairs_sum == max_val)
        if greedy:
            max_idx = max_list[0]
        else:
            max_idx = random.choice(max_list)        
        pairs.append(max_idx)
        # Remove by setting row and col to zero for both
        pairs_sum[max_idx[0], :] = 0
        pairs_sum[max_idx[1], :] = 0
        pairs_sum[:, max_idx[0]] = 0
        pairs_sum[:, max_idx[1]] = 0
    return pairs

# pairs_list = find_pairs(pairs_sum, upper_limit=4.9, greedy=False)

# rows = []
# for idx1, idx2 in pairs_list:
#     row = []
#     row.append( df.iloc[idx1, 0] )
#     row.append( df.iloc[idx1, 1] )
#     if idx1!=idx2:
#         row.append( df.iloc[idx2, 0] )
#         row.append( df.iloc[idx2, 1] )
#         row.append( df.iloc[idx1, 1]+df.iloc[idx2, 1] )
#     else:
#         row.append( "" )
#         row.append( 0 )
#         row.append( df.iloc[idx1, 1] )

#     rows.append(row)
# pd.DataFrame(rows, columns=["title1", "gb1", "title2", "gb2", "gb_sum"])
